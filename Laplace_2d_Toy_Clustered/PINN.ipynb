# %% [markdown]
# # PINN for Laplace Equation - Training on Dataset
# (Please reference to our paper **Physics-Informed Boundary Integral Networks (PIBI-Nets): a Data-Driven Approach for Solving Partial Differential Equations**.)
#
#
# ## Problem setup
#
# ### Laplace equation
# $$ \Delta u(x) := \frac{\partial^2 u}{\partial x_1^2} + \frac{\partial^2 u}{\partial x_2^2} = 0 $$
#
# $$x:=(x_1, x_2)\, \in \,\left([-1,1]\times [-1,1]\right)=:\Omega \subseteq \mathbb{R}^2$$
#
# ### Uniformal sampled datapoints based on FD solution given by Dirichlet boundary conditions
# Let ${\large\{}u_i(x){\large\}}_{i=0}^{i=N}$ be the measurements constructed by a finite difference solution of the Laplace equation based on Dirichlet boundary conditions

# %% [markdown]
# ## Initial settings

# %%
# load packages
import torch
import torch.nn as nn
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm 
from matplotlib.font_manager import FontProperties
import pandas as pd
import os

# %%
# plot specifications
matplotlib.rcParams['text.usetex'] = True
# font properties for axis
font_axis = FontProperties()
font_axis.set_family('serif')
font_axis.set_name('Times New Roman')
font_axis.set_size(115) 
# font properties for 3d plot axis
font_axis_3d = FontProperties()
font_axis_3d.set_family('serif')
font_axis_3d.set_name('Times New Roman')
font_axis_3d.set_size(90)

# %% [markdown]
# ## Dataset setup

# %%
# read data from CSV file 
def read_data(csv_file):
    """
    read csv file and store data in x_data, u_data
    
    Args:
    - csv_file
    
    Returns:
    - x_data: tensor of shape (N,2) containing N positions x=(x1,x2)
    - u_data: tensor of shape (N,1) containing u values to corresponding x
    
    """   
    
    # read data from CSV file 
    data_pd = pd.read_csv(csv_file)
    data_tensor = torch.tensor(data_pd.values, dtype=torch.float32) # x1, x2, u
    x_data = data_tensor[:,0:2] 
    u_data = data_tensor[:,2].view(-1,1)
    
    return x_data, u_data

x_data, u_data = read_data('dataset_laplace.csv')

# %%
x_new = []
u_new = []
x_remove = []
x_data = np.array(x_data)
u_data = np.array(u_data)
limit = 0.8

for k in range(u_data.shape[0]):
    if (-limit < x_data[k,0]) & (x_data[k,0]<limit) & (-limit < x_data[k,1]) & (x_data[k,1]<limit):
        x_remove.append(x_data[k,:])
    else:
        x_new.append(x_data[k,:])
        u_new.append(u_data[k,:])

        
x_data = torch.tensor(np.array(x_new))
u_data = torch.tensor(np.array(u_new))
x_data.shape
# Out:
# torch.Size([30, 2])

# %% [markdown]
# ## Finite difference solution

# %%
# read data from CSV file 
x_num = pd.read_csv('X_mesh.csv')
x_num = torch.tensor(x_num.values, dtype=torch.float32) 

# read data from CSV file
u_num = pd.read_csv('u_num.csv')
u_num = torch.tensor(u_num.values, dtype=torch.float32) 

N = u_num.shape
N
# Out:
# torch.Size([10201, 1])

# %% [markdown]
# ## Collocation points

# %%
def collocation_points(n):

    # number of collocation points over entire domain for physics / pde loss
    x1_collocation = torch.FloatTensor(n, 1).uniform_(-1, 1)
    x2_collocation = torch.FloatTensor(n, 1).uniform_(-1, 1)
    x_collocation = torch.cat([x1_collocation, x2_collocation], axis=1).requires_grad_(True) 
    
    return x_collocation

# %% [markdown]
# ## Physics initialisation

# %%
#  pde function, given a network nnet
def pde(x, u):
    """
    computes physics given by pde, where solution u of pde is computed by neural network net at position x=(x1,x2) in Omega
    
    Args:
    - x: tensor of shape (N,2) containing N positions (x1, x2) in Omega
    - u: tensor of shape (N,1) given by neural network that has 2 dimensional first layer and a one dimensional output layer
    
    Returns:
    - u_pde: tensor of shape (N,1) containing the pde at each position in x
    
    """   
    
    # compute gradients for pde
    du_dx = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True)[0] # (du_dx1, du_dx2) of shape (N,2)
    d2u_dx1x1 = torch.autograd.grad(du_dx[:,0], x, grad_outputs=torch.ones_like(du_dx[:,0]), create_graph=True)[0][:,0].view(-1,1) # (d2u_dx1x1, d2u_dx1x2), but only take first column, shape (N,1)
    d2u_dx2x2 = torch.autograd.grad(du_dx[:,1], x, grad_outputs=torch.ones_like(du_dx[:,1]), create_graph=True)[0][:,1].view(-1,1) # (d2u_dx2x1, d2u_dx2x2), but only take second column, shape (N,1)
    
    # compute pde
    u_pde = d2u_dx1x1 + d2u_dx2x2
    
    return u_pde

# %% [markdown]
# ## Network setup

# %%
# fully-connected neural network setup with PyTorch
class FCNN(nn.Module):
    def __init__(self, N_input, N_output, N_hidden, N_layers):
        """
        class implementation of a fully-connected neural network with PyTorch given by Args
        
        Args:
        - N_input: integer, number of input dimension, here N_input = 2 given by x=(x1, x2)
        - N_output: integer, number of output dimession, here N_output = 1 given by u(x)
        - N_hidden: integer, depth of one hidden layer
        - N_layers: integer, number of hidden layers in the network
        
        Methods:
        - forward: forward pass of neural network
        
        """  
        super().__init__()  
        activation = nn.Tanh
        
        #self.myparam = nn.Parameter(nn.ones((1,)))
        
        # input / start layer
        self.fc_start = nn.Sequential(*[ 
                                nn.Linear(N_input, N_hidden),
                                activation()
                                ])
        # hidden layers
        self.fc_hidden = nn.Sequential(*[
                                nn.Sequential(*[
                                    nn.Linear(N_hidden, N_hidden),
                                    activation()
                                    ]) 
                                for _ in range(N_layers-1) # -1 since first layer already defined before for-loop
                                ])
        # output / end layer
        self.fc_end = nn.Linear(N_hidden, N_output)
        
        
    def forward(self, x):
        """
        forward pass through network building blocks given in this class above
        
        Args:
        - x: tensor of shape (N, 2) containing N positions (x1, x2)

        Returns:
        - u: tensor of shape (N,1) containing the network solution u at position x
        
        """ 
        # forward network
        x = self.fc_start(x)  # input layer
        x = self.fc_hidden(x) # hidden layer(s)
        u = self.fc_end(x)    # output layer   
        
        return u

# %%
def initialise_pinn(lr):
    # define number of neurons in each layer type
    N_input  = 2
    N_output = 1
    N_hidden = 512 
    N_layers = 3 # number of hidden layers

    # define a neural network to train
    pinn = FCNN(N_input, N_output, N_hidden, N_layers)

    # optimizer
    optimiser = torch.optim.Adam(pinn.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser, factor=0.5, eps=1e-12, verbose=True)

    # loss function
    mse_loss = torch.nn.MSELoss()
    
    return pinn, optimiser, scheduler, mse_loss

# %% [markdown]
# ## Train PINN and visualise trained solution

# %%
def train_pinn(iterations, lambda_physics, n_coll, pinn, optimiser, scheduler, mse_loss):

    # store loss values
    loss_values = []

    for epoch in range(iterations):
        optimiser.zero_grad()

        # compute data loss
        u = pinn(x_data)
        loss_data = mse_loss(u, u_data)

        # compute physics loss
        x_collocation = collocation_points(n)
        u = pinn(x_collocation)
        loss_pde = (mse_loss(torch.zeros_like(u), pde(x_collocation, u)))

        # backpropagate weighted joint loss, take optimiser step
        loss = loss_data + lambda_physics*loss_pde
        loss_values.append(loss.item()) 
        loss.backward()
        optimiser.step()
        scheduler.step(loss)

        # plot result as training progresses on test set
        if epoch % 10 == 0: 
            print('epoch:', epoch, ', data:', loss_data.data, 'physics:', loss_pde.data)

            if epoch == iterations-1: 
                torch.save(pinn.state_dict(), "pinn_model.pt")
                
                u = torch.squeeze(pinn(x_num).detach()) 
                # variables on grid X1_test, X2_test
                x1 = (x_num[:,0]).reshape((101, 101))
                x2 = (x_num[:,1]).reshape((101, 101)) 
                u_nn = u.reshape(x1.shape) 
                
                # evaluation plot in 3D
                fig = plt.figure(figsize=(15,15))
                ax = fig.add_subplot(111, projection='3d', computed_zorder=False)
                surf = ax.plot_surface(x1, x2, u_nn, cmap=cm.jet, zorder=1, alpha=1)
                ax.scatter(x_data[:,0], x_data[:,1], u_data, c='black', marker='o', s=10**2, alpha=1, zorder=2)
                surf.set_clim(vmin=-1, vmax=1) 
                fig.axes[0].tick_params(axis="both", labelsize=20)
                # axis ticks
                ax.tick_params(axis="both", labelsize=60, pad=20)
                major_ticks = [-1,-0.5,0, 0.5,1]
                ax.set_xticks(major_ticks)
                ax.set_yticks(major_ticks)
                ax.set_zticks(major_ticks)
                # tick colour
                ax.tick_params(axis='x', colors='grey')
                ax.tick_params(axis='y', colors='grey')
                ax.tick_params(axis='z', colors='grey')
                # labels
                ax.set_xlabel('$x_1$', fontproperties=font_axis_3d, labelpad=55)
                ax.set_ylabel('$x_2$', fontproperties=font_axis_3d, labelpad=55)
                ax.set_zlabel('$u$', fontproperties=font_axis_3d, labelpad=55)
                # Save the figure as a JPEG image
                plt.savefig('pinn_3d_bc.jpg', dpi=500, format='jpeg', bbox_inches='tight')
                plt.show()
                
                # evaluation plot in 2d
                fig, ax = plt.subplots(figsize=(15, 15))
                img = ax.imshow(u_nn, cmap='jet', origin='lower', 
                                extent=[torch.min(x1).item(), torch.max(x1).item(), 
                                        torch.min(x2).item(), torch.max(x2).item()],
                                vmin=-1, vmax=1)
                ax.scatter(x_data[:,0], x_data[:,1], c='black', marker='o', s=10**2, alpha=1, zorder=4)
                fig.axes[0].tick_params(axis="both", labelsize=20)
                # axis ticks
                ax.tick_params(axis="both", labelsize=70, pad=5)
                major_ticks = [-1,-0.5,0, 0.5,1]
                ax.set_xticks(major_ticks)
                ax.set_yticks(major_ticks)
                # tick colour
                ax.tick_params(axis='x', colors='grey')
                ax.tick_params(axis='y', colors='grey')
                # labels
                ax.set_xlabel('$x_1$', fontproperties=font_axis, labelpad=0)
                ax.set_ylabel('$x_2$', fontproperties=font_axis, labelpad=-20)
                # Save the figure as a JPEG image
                plt.savefig('pinn_2d_bc.jpg', dpi=500, format='jpeg', bbox_inches='tight')
                plt.show()
                
                # absolute error plot
                u_num_matrix = u_num.reshape(u_nn.shape)
                u_error = torch.abs(u_nn-u_num_matrix)
                fig, ax = plt.subplots(figsize=(15, 15))
                img = ax.imshow(u_error, cmap='jet_r', origin='lower', 
                                extent=[torch.min(x1).item(), torch.max(x1).item(), 
                                        torch.min(x2).item(), torch.max(x2).item()], 
                                vmin=0, vmax=1.1)
                ax.scatter(x_data[:,0], x_data[:,1], c='black', marker='o', s=10**2, alpha=1, zorder=4)
                fig.axes[0].tick_params(axis="both", labelsize=20)
                # axis ticks
                ax.tick_params(axis="both", labelsize=70, pad=5)
                major_ticks = [-1,-0.5,0, 0.5,1]
                ax.set_xticks(major_ticks)
                ax.set_yticks(major_ticks)
                # tick colour
                ax.tick_params(axis='x', colors='grey')
                ax.tick_params(axis='y', colors='grey')
                # labels
                ax.set_xlabel('$x_1$', fontproperties=font_axis, labelpad=0)
                ax.set_ylabel('$x_2$', fontproperties=font_axis, labelpad=-20)
                plt.savefig('pinn_error_bc.jpg', dpi=500, format='jpeg', bbox_inches='tight')
                plt.show()
                u_vec = u_error.reshape(N,1)
                print('min', torch.min(u_vec), 'max', torch.max(u_vec), 'mean', torch.mean(u_vec))
        
    return loss_values, pinn

# %%
# pinn initialisation
lr = 5e-4 # learning rate
pinn, optimiser, scheduler, mse_loss = initialise_pinn(lr)
    
iterations = 2_001
lambda_physics = 1e-6 # weighting of physics loss
n = 1000 # number of collocation points
loss_values, pinn = train_pinn(iterations, lambda_physics, n, pinn, optimiser, scheduler, mse_loss)
# Out:
# epoch: 0 , data: tensor(0.2823) physics: tensor(0.0004)
# epoch: 10 , data: tensor(0.1132) physics: tensor(0.0640)
# epoch: 20 , data: tensor(0.0939) physics: tensor(0.0861)
# epoch: 30 , data: tensor(0.0699) physics: tensor(0.1880)
# epoch: 40 , data: tensor(0.0519) physics: tensor(0.4266)
# epoch: 50 , data: tensor(0.0421) physics: tensor(0.8123)
# epoch: 60 , data: tensor(0.0388) physics: tensor(1.3360)
# epoch: 70 , data: tensor(0.0354) physics: tensor(1.6863)
# epoch: 80 , data: tensor(0.0331) physics: tensor(1.9631)
# epoch: 90 , data: tensor(0.0312) physics: tensor(2.4777)
# epoch: 100 , data: tensor(0.0296) physics: tensor(3.3534)
# epoch: 110 , data: tensor(0.0282) physics: tensor(3.6605)
# epoch: 120 , data: tensor(0.0293) physics: tensor(4.0713)
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# epoch: 130 , data: tensor(0.0266) physics: tensor(4.3539)
# epoch: 1020 , data: tensor(0.0008) physics: tensor(51.0442)
# epoch: 1030 , data: tensor(0.0008) physics: tensor(52.0555)
# epoch: 1040 , data: tensor(0.0008) physics: tensor(55.3199)
# epoch: 1050 , data: tensor(0.0008) physics: tensor(52.4987)
# epoch: 1060 , data: tensor(0.0008) physics: tensor(58.6240)
# epoch: 1070 , data: tensor(0.0008) physics: tensor(52.0997)
# epoch: 1080 , data: tensor(0.0008) physics: tensor(50.2791)
# Epoch 01091: reducing learning rate of group 0 to 6.2500e-05.
# epoch: 1090 , data: tensor(0.0017) physics: tensor(50.3494)
# epoch: 1100 , data: tensor(0.0009) physics: tensor(52.2463)
# Epoch 01104: reducing learning rate of group 0 to 3.1250e-05.
# epoch: 1110 , data: tensor(0.0009) physics: tensor(55.0242)
# Epoch 01115: reducing learning rate of group 0 to 1.5625e-05.
# epoch: 1120 , data: tensor(0.0008) physics: tensor(52.2557)
# epoch: 1130 , data: tensor(0.0008) physics: tensor(57.6970)
# Epoch 01135: reducing learning rate of group 0 to 7.8125e-06.
# epoch: 1140 , data: tensor(0.0008) physics: tensor(53.0014)
# epoch: 1150 , data: tensor(0.0008) physics: tensor(51.1269)
# epoch: 1160 , data: tensor(0.0008) physics: tensor(53.6997)
# Epoch 01163: reducing learning rate of group 0 to 3.9063e-06.
# epoch: 1170 , data: tensor(0.0008) physics: tensor(47.4792)
# epoch: 1180 , data: tensor(0.0008) physics: tensor(53.3785)
# epoch: 1190 , data: tensor(0.0008) physics: tensor(48.5445)
# Epoch 01197: reducing learning rate of group 0 to 1.9531e-06.
# epoch: 1200 , data: tensor(0.0008) physics: tensor(50.7976)
# Epoch 01208: reducing learning rate of group 0 to 9.7656e-07.
# epoch: 1210 , data: tensor(0.0008) physics: tensor(46.7463)
# Epoch 01219: reducing learning rate of group 0 to 4.8828e-07.
# epoch: 1220 , data: tensor(0.0008) physics: tensor(54.7252)
# epoch: 1230 , data: tensor(0.0008) physics: tensor(49.7874)
# Epoch 01241: reducing learning rate of group 0 to 2.4414e-07.
# epoch: 1240 , data: tensor(0.0008) physics: tensor(52.2101)
# epoch: 1250 , data: tensor(0.0008) physics: tensor(50.3041)
# Epoch 01252: reducing learning rate of group 0 to 1.2207e-07.
# epoch: 1260 , data: tensor(0.0008) physics: tensor(52.0981)
# Epoch 01263: reducing learning rate of group 0 to 6.1035e-08.
# epoch: 1270 , data: tensor(0.0008) physics: tensor(45.2325)
# Epoch 01274: reducing learning rate of group 0 to 3.0518e-08.
# epoch: 1280 , data: tensor(0.0008) physics: tensor(50.1185)
# Epoch 01285: reducing learning rate of group 0 to 1.5259e-08.
# epoch: 1290 , data: tensor(0.0008) physics: tensor(53.0024)
# Epoch 01296: reducing learning rate of group 0 to 7.6294e-09.
# epoch: 1300 , data: tensor(0.0008) physics: tensor(50.1094)
# Epoch 01307: reducing learning rate of group 0 to 3.8147e-09.
# epoch: 1310 , data: tensor(0.0008) physics: tensor(50.3587)
# Epoch 01318: reducing learning rate of group 0 to 1.9073e-09.
# epoch: 1320 , data: tensor(0.0008) physics: tensor(48.5918)
# Epoch 01329: reducing learning rate of group 0 to 9.5367e-10.
# epoch: 1330 , data: tensor(0.0008) physics: tensor(56.9645)
# Epoch 01340: reducing learning rate of group 0 to 4.7684e-10.
# epoch: 1340 , data: tensor(0.0008) physics: tensor(54.6117)
# Epoch 01351: reducing learning rate of group 0 to 2.3842e-10.
# epoch: 1350 , data: tensor(0.0008) physics: tensor(53.0027)
# epoch: 1360 , data: tensor(0.0008) physics: tensor(49.0051)
# Epoch 01362: reducing learning rate of group 0 to 1.1921e-10.
# epoch: 1370 , data: tensor(0.0008) physics: tensor(50.3965)
# Epoch 01373: reducing learning rate of group 0 to 5.9605e-11.
# epoch: 1380 , data: tensor(0.0008) physics: tensor(52.8938)
# Epoch 01384: reducing learning rate of group 0 to 2.9802e-11.
# epoch: 1390 , data: tensor(0.0008) physics: tensor(51.9862)
# Epoch 01395: reducing learning rate of group 0 to 1.4901e-11.
# epoch: 1400 , data: tensor(0.0008) physics: tensor(59.9591)
# Epoch 01406: reducing learning rate of group 0 to 7.4506e-12.
# epoch: 1410 , data: tensor(0.0008) physics: tensor(52.4874)
# epoch: 1420 , data: tensor(0.0008) physics: tensor(48.8783)
# Epoch 01423: reducing learning rate of group 0 to 3.7253e-12.
# epoch: 1430 , data: tensor(0.0008) physics: tensor(53.9033)
# Epoch 01434: reducing learning rate of group 0 to 1.8626e-12.
# epoch: 1440 , data: tensor(0.0008) physics: tensor(56.0277)
# epoch: 1450 , data: tensor(0.0008) physics: tensor(54.5357)
# epoch: 1460 , data: tensor(0.0008) physics: tensor(54.7065)
# epoch: 1470 , data: tensor(0.0008) physics: tensor(53.3145)
# epoch: 1480 , data: tensor(0.0008) physics: tensor(49.6212)
# epoch: 1490 , data: tensor(0.0008) physics: tensor(53.2759)
# epoch: 1500 , data: tensor(0.0008) physics: tensor(55.5507)
# epoch: 1510 , data: tensor(0.0008) physics: tensor(49.7498)
# epoch: 1520 , data: tensor(0.0008) physics: tensor(52.9521)
# epoch: 1530 , data: tensor(0.0008) physics: tensor(51.6200)
# epoch: 1540 , data: tensor(0.0008) physics: tensor(51.1698)
# epoch: 1550 , data: tensor(0.0008) physics: tensor(49.5031)
# epoch: 1560 , data: tensor(0.0008) physics: tensor(55.9356)
# epoch: 1570 , data: tensor(0.0008) physics: tensor(58.3772)
# epoch: 1580 , data: tensor(0.0008) physics: tensor(50.9801)
# epoch: 1590 , data: tensor(0.0008) physics: tensor(54.6496)
# epoch: 1600 , data: tensor(0.0008) physics: tensor(55.4681)
# epoch: 1610 , data: tensor(0.0008) physics: tensor(51.5652)
# epoch: 1620 , data: tensor(0.0008) physics: tensor(53.5854)
# epoch: 1630 , data: tensor(0.0008) physics: tensor(49.9476)
# epoch: 1640 , data: tensor(0.0008) physics: tensor(46.2802)
# epoch: 1650 , data: tensor(0.0008) physics: tensor(53.9035)
# epoch: 1660 , data: tensor(0.0008) physics: tensor(55.7375)
# epoch: 1670 , data: tensor(0.0008) physics: tensor(52.5592)
# epoch: 1680 , data: tensor(0.0008) physics: tensor(46.1555)
# epoch: 1690 , data: tensor(0.0008) physics: tensor(52.6404)
# epoch: 1700 , data: tensor(0.0008) physics: tensor(51.1062)
# epoch: 1710 , data: tensor(0.0008) physics: tensor(53.7431)
# epoch: 1720 , data: tensor(0.0008) physics: tensor(54.7215)
# epoch: 1730 , data: tensor(0.0008) physics: tensor(52.6614)
# epoch: 1740 , data: tensor(0.0008) physics: tensor(51.2859)
# epoch: 1750 , data: tensor(0.0008) physics: tensor(53.4142)
# epoch: 1760 , data: tensor(0.0008) physics: tensor(51.3415)
# epoch: 1770 , data: tensor(0.0008) physics: tensor(54.3972)
# epoch: 1780 , data: tensor(0.0008) physics: tensor(54.9542)
# epoch: 1790 , data: tensor(0.0008) physics: tensor(57.0143)
# epoch: 1800 , data: tensor(0.0008) physics: tensor(51.6697)
# epoch: 1810 , data: tensor(0.0008) physics: tensor(46.7203)
# epoch: 1820 , data: tensor(0.0008) physics: tensor(50.0443)
# epoch: 1830 , data: tensor(0.0008) physics: tensor(52.1914)
# epoch: 1840 , data: tensor(0.0008) physics: tensor(51.2744)
# epoch: 1850 , data: tensor(0.0008) physics: tensor(50.7601)
# epoch: 1860 , data: tensor(0.0008) physics: tensor(56.9765)
# epoch: 1870 , data: tensor(0.0008) physics: tensor(51.6536)
# epoch: 1880 , data: tensor(0.0008) physics: tensor(51.6321)
# epoch: 1890 , data: tensor(0.0008) physics: tensor(56.3874)
# epoch: 1900 , data: tensor(0.0008) physics: tensor(53.3494)
# epoch: 1910 , data: tensor(0.0008) physics: tensor(49.8286)
# epoch: 1920 , data: tensor(0.0008) physics: tensor(50.3045)
# epoch: 1930 , data: tensor(0.0008) physics: tensor(48.4915)
# epoch: 1940 , data: tensor(0.0008) physics: tensor(52.6338)
# epoch: 1950 , data: tensor(0.0008) physics: tensor(48.8456)
# epoch: 1960 , data: tensor(0.0008) physics: tensor(50.8677)
# epoch: 1970 , data: tensor(0.0008) physics: tensor(49.6992)
# epoch: 1980 , data: tensor(0.0008) physics: tensor(48.4726)
# epoch: 1990 , data: tensor(0.0008) physics: tensor(58.6086)
# epoch: 2000 , data: tensor(0.0008) physics: tensor(47.9269)
# min tensor(1.6987e-05) max tensor(0.9171) mean tensor(0.1938)

# %% [markdown]
# # Visualize convergence of loss function

# %%
epochs = list(range(1,iterations+1))
fig, ax = plt.subplots()
ax.plot(epochs, loss_values)
ax.set(xlabel='epochs / iterations', 
       ylabel='loss',
       title='Convergence')
#plt.savefig('pinn_loss.jpg', dpi=500, format='jpeg', bbox_inches='tight')
plt.show()
